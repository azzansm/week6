# %%
# exercise 1
inventory = {
 'gold' : 500,
 'pouch' : ['flint', 'twine', 'gemstone'],
 'backpack' : ['xylophone','dagger', 'bedroll','bread loaf']
}

# add a key to inventory called 'pocket'
inventory.setdefault('pocket')

# set the value of 'pocket' to be a list consisting of the strings 'seashell', 'strange berry', and 'lint'
inventory['pocket'] = ['seashell','strange berry','lint']

# sort()the items in the list stored under the 'backpack' key
inventory['backpack'].sort()

# .remove('dagger') from the list of items stored under the 'backpack' key
inventory['backpack'].remove('dagger')

# add 50 to the number stored under the 'gold' key
inventory['gold'] += 50

print(inventory)
# Out:
# {'gold': 550, 'pouch': ['flint', 'twine', 'gemstone'], 'backpack': ['bedroll', 'bread loaf', 'xylophone'], 'pocket': ['seashell', 'strange berry', 'lint']}

# %%
# exercise 2
stock = {
 "banana": 6,
 "apple": 0,
 "orange": 32,
 "pear": 15
}
prices = {
 "banana": 4,
 "apple": 2,
 "orange": 1.5,
 "pear": 3
}

# create a variable called total and set it to zero
total = 0
for i in prices:
    print(i)
    print('price: %s' %prices[i])
    print('stock: %s' %stock[i])

# loop through the prices dictionaries
    total += stock[i]*prices[i]

# print total
print("Total:", total)
# Out:
# banana
# price: 4
# stock: 6
# apple
# price: 2
# stock: 0
# orange
# price: 1.5
# stock: 32
# pear
# price: 3
# stock: 15
# Total: 117.0

# %%
# exercise 3
# make a list called groceries with the values "banana","orange", and "apple"
groceries = ['banana','orange','apple']

stock = {
"banana": 6,
"apple": 0,
"orange": 32,
"pear": 15
}

prices = {
"banana": 4,
"apple": 2,
"orange": 1.5,
"pear": 3
}

food = ['banana', 'apple','orange','pear']

# define a function compute_bill
def compute_bill(food):
    total = 0
#   for i in food:
#     total += prices[i]
#   return total
    
# make the following changes to your function
    for i in food:
        if stock[i] > 0:
            total += prices[i]
            stock[i] -= 1
        
# return the total
    return total

print("Total price:", compute_bill(groceries))
# Out:
# Total price: 5.5

# %%
# exercise 4
# create three dictionaries: eren, mikasa, and armin
# give each dict the keys 'name','homework','quizzes', and 'tests'
eren = {
 "name": "Eren",
 "homework": [90.0,97.0,75.0,92.0],
 "quizzes": [88.0,40.0,94.0],
 "tests": [75.0,90.0]
}
mikasa = {
"name": "Mikasa",
"homework": [100.0, 92.0, 98.0, 100.0],
"quizzes": [82.0, 83.0, 91.0],
"tests": [89.0, 97.0]
}
armin = {
"name": "Armin",
"homework": [0.0, 87.0, 75.0, 22.0],
"quizzes": [0.0, 75.0, 78.0],
"tests": [100.0, 100.0]
}

#create a list called students that contains eren, mikasa, and armin
students = [eren, mikasa, armin]

# print out that students's data
for item in students:
    print("Name:",item['name'])
    print("Homework:",item['homework'])
    print("Quizzes:",item['quizzes'])
    print("Tests:",item['tests'])
    print()

# write a function avg that takes a list of numbers and returns the avg
def average(numbers):
    total = float(sum(numbers))
    return total / len(numbers)

# write a function called get_average that takes a student dict and returns his/her weighted avg
def get_average(student):
    homework = average(student['homework'])
    quizzes = average(student['quizzes'])
    tests = average(student['tests'])
    return (0.1*homework) + (0.3*quizzes) + (0.6*tests)

# define a new function called get_letter_grade that has one argument called score
def get_letter_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >=70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'F'

print("Mikasa's grade:",get_average(mikasa))

# define a function called get_class_average that has one argument, students
def get_class_average(students):
    results = []
    for item in students:
        results.append(get_average(item))
    return average(results)

# print out the result of calling get_class_average with your students list
print("Class average:",get_class_average(students))

# then, print the result of get_letter_grade for the class's average
print("Class average (in letter):",get_letter_grade(get_class_average(students)))
# Out:
# Name: Eren
# Homework: [90.0, 97.0, 75.0, 92.0]
# Quizzes: [88.0, 40.0, 94.0]
# Tests: [75.0, 90.0]
#
# Name: Mikasa
# Homework: [100.0, 92.0, 98.0, 100.0]
# Quizzes: [82.0, 83.0, 91.0]
# Tests: [89.0, 97.0]
#
# Name: Armin
# Homework: [0.0, 87.0, 75.0, 22.0]
# Quizzes: [0.0, 75.0, 78.0]
# Tests: [100.0, 100.0]
#
# Mikasa's grade: 91.14999999999999
# Class average: 83.86666666666666
# Class average (in letter): B
